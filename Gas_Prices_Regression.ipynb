# %% [markdown]
# # Introduction
# >The National Agency of Petroleum, Natural Gas and Bio fuels (ANP in Portuguese) releases weekly reports of gas, diesel and other fuels prices used in transportation across the country. These datasets bring the mean value per liter, number of gas stations analyzed and other information grouped by regions and states across the country.
#
# >![image.png](data:image/png;base64,...)
#
# >For more information about dataset and problem : https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil

# %% [markdown]
# ### **Featurs in Dataset**
#
# Unnamed: 0 : Unique ID
#
# DATA INICIAL : First day of analyses in the week
#
# DATA FINAL : Last day of analyses in the week
#
# REGIÃO : Macro region
# ESTADO : State
#
# PRODUTO : Kind of Product
#
# NÚMERO DE POSTOS PESQUISADOS : Number of Gas Stations analyzed
#
# UNIDADE DE MEDIDA : Measurement unit
#
# PREÇO MÉDIO REVENDA : Mean Market Price
#
# DESVIO PADRÃO REVENDA : Standard Deviation Price
#
# PREÇO MÍNIMO REVENDA : Min Price observed
#
# PREÇO MÁXIMO REVENDA : Max Price Observed
#
# MARGEM MÉDIA REVENDA : Mean Price Margin
#
# COEF DE VARIAÇÃO REVENDA : Coefficient of variation
#
# PREÇO MÉDIO DISTRIBUIÇÃO : Mean Distribution Price
#
# DESVIO PADRÃO DISTRIBUIÇÃO : Distribution standard deviation
#
# PREÇO MÍNIMO DISTRIBUIÇÃO : Distribution Min Price
#
# PREÇO MÁXIMO DISTRIBUIÇÃO : Distribution Max Price
#
# COEF DE VARIAÇÃO DISTRIBUIÇÃO : Distribution's coefficient of variation
#
# MÊS : Month
#
# ANO : Year

# %% [markdown]
# # 1. Imporing Libraries and Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy  as np
# %matplotlib inline
sns.set(rc={'figure.figsize':(8, 8)}, font_scale=1.3)

# %%
df = pd.read_csv('2004-2019.tsv',sep='\t')

# %% [markdown]
# # Data Preprocessing

# %%
df.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  \
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA
# 0  ETANOL HIDRATADO                           127              R$/l  \
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA
# 0               1.2880                 0.0160  ...                1.3500  \
# 1               1.1620                 0.1140  ...                1.4490
# 2               1.3890                 0.0970  ...                1.7600
# 3               1.2620                 0.0700  ...                1.5090
# 4               1.1810                 0.0780  ...                1.4000
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# 0                 0.463                   0.0120                     0.825  \
# 1                 0.399                   0.0980                     0.763
# 2                 0.419                   0.0700                      0.97
# 3                 0.432                   0.0550                      0.83
# 4                  0.24                   0.0660                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO
# 0                       0.11                    0.4201  \
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO
# 106818      106818   2019-06-23  2019-06-29  NORDESTE  RIO GRANDE DO NORTE  \
# 106819      106819   2019-06-23  2019-06-29       SUL    RIO GRANDE DO SUL
# 106820      106820   2019-06-23  2019-06-29       SUL       SANTA CATARINA
# 106821      106821   2019-06-23  2019-06-29   SUDESTE            SAO PAULO
# 106822      106822   2019-06-23  2019-06-29  NORDESTE              SERGIPE
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA
# 106818     GNV                             7             R$/m3  \
# 106819     GNV                            23             R$/m3
# 106820     GNV                            24             R$/m3
# 106821     GNV                            52             R$/m3
# 106822     GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA
# 106818               3.5740                 0.0650  ...                3.6900  \
# 106819               3.4010                 0.1290  ...                3.7890
# 106820               2.9120                 0.1900  ...                3.4990
# 106821               3.0200                 0.2290  ...                3.4900
# 106822               3.6970                 0.0050  ...                3.6990
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA
# 106818                 0.818                   0.0180  \
# 106819                  0.95                   0.0380
# 106820                 0.914                   0.0650
# 106821                 0.646                   0.0760
# 106822                 1.179                   0.0010
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO
# 106818                     2.756                          0  \
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO
# 106818                     2.756                     2.756  \
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [5 rows x 21 columns]

# %%
df.sample(5)
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO          ESTADO
# 55977       55977   2013-01-13  2013-01-19  NORDESTE      PERNAMBUCO  \
# 61776       61776   2013-10-06  2013-10-12  NORDESTE         SERGIPE
# 24827       24827   2004-10-31  2004-11-06   SUDESTE  ESPIRITO SANTO
# 76688       76688   2015-08-30  2015-09-05  NORDESTE         PARAIBA
# 94231       94231   2017-11-19  2017-11-25     NORTE            PARA
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA
# 55977  ÓLEO DIESEL S10                           162              R$/l  \
# 61776  ÓLEO DIESEL S10                            30              R$/l
# 24827              GLP                           245           R$/13Kg
# 76688      ÓLEO DIESEL                            27              R$/l
# 94231      ÓLEO DIESEL                            39              R$/l
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA
# 55977               2.1640                 0.0430  ...                2.3400  \
# 61776               2.4710                 0.0840  ...                2.5990
# 24827              28.9500                 1.7340  ...               34.0000
# 76688               2.7530                 0.0880  ...                2.8900
# 94231               3.4700                 0.2020  ...                3.8600
#
#        MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA
# 55977                 0.203                   0.0200  \
# 61776                 0.275                   0.0340
# 24827                 4.832                   0.0600
# 76688                 0.208                   0.0320
# 94231                 0.369                   0.0580
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO
# 55977                     1.961                      0.037  \
# 61776                     2.196                       0.06
# 24827                    24.118                      1.935
# 76688                     2.545                      0.069
# 94231                     3.101                        0.1
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO
# 55977                     1.905                    2.0692  \
# 61776                    2.1012                     2.277
# 24827                        21                     28.98
# 76688                    2.4288                    2.6414
# 94231                     2.864                     3.152
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 55977                         0.019   1  2013
# 61776                         0.027  10  2013
# 24827                          0.08  10  2004
# 76688                         0.027   8  2015
# 94231                         0.032  11  2017
#
# [5 rows x 21 columns]

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
# Renaming Columns as it isn't written in english
df.rename(columns={
        "DATA INICIAL": "start_date",
        "DATA FINAL": "end_date",
        "REGIÃO": "region",
        "ESTADO": "state",
        "PRODUTO": "Product_Kind",
        "NÚMERO DE POSTOS PESQUISADOS": "n_gas_stations",
        "UNIDADE DE MEDIDA": "Measuring unit",
        "PREÇO MÉDIO REVENDA": "avg_price",
        "DESVIO PADRÃO REVENDA": "sd_price",
        "PREÇO MÍNIMO REVENDA": "min_price",
        "PREÇO MÁXIMO REVENDA": "max_price",
        "MARGEM MÉDIA REVENDA": "avg_price_margin",
        "ANO": "year",
        "MÊS": "month",
        "COEF DE VARIAÇÃO DISTRIBUIÇÃO": "coef_dist",
        "PREÇO MÁXIMO DISTRIBUIÇÃO": "dist_max_price",
        "PREÇO MÍNIMO DISTRIBUIÇÃO": "dist_min_price",
        "DESVIO PADRÃO DISTRIBUIÇÃO": "dist_sd_price",
        "PREÇO MÉDIO DISTRIBUIÇÃO": "dist_avg_price",
        "COEF DE VARIAÇÃO REVENDA": "coef_price"
    }, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   start_date        106823 non-null  object
#  1   end_date          106823 non-null  object
#  2   region            106823 non-null  object
#  3   state             106823 non-null  object
#  4   Product_Kind      106823 non-null  object
#  5   n_gas_stations    106823 non-null  int64
#  6   Measuring unit    106823 non-null  object
#  7   avg_price         106823 non-null  float64
#  8   sd_price          106823 non-null  float64
#  9   min_price         106823 non-null  float64
#  10  max_price         106823 non-null  float64
#  11  avg_price_margin  106823 non-null  object
#  12  coef_price        106823 non-null  float64
#  13  dist_avg_price    106823 non-null  object
#  14  dist_sd_price     106823 non-null  object
#  15  dist_min_price    106823 non-null  object
#  16  dist_max_price    106823 non-null  object
#  17  coef_dist         106823 non-null  object
#  18  month             106823 non-null  int64
#  19  year              106823 non-null  int64
# dtypes: float64(5), int64(3), object(12)
# memory usage: 16.3+ MB

# %%
df.describe()
# Out:
#        n_gas_stations   avg_price    sd_price   min_price   max_price
# count     106823.0000 106823.0000 106823.0000 106823.0000 106823.0000  \
# mean         233.7710     10.8708      0.6572      9.4160     12.5377
# std          403.2825     17.7525      1.3492     15.0922     20.8415
# min            1.0000      0.7660      0.0000      0.5900      0.9990
# 25%           42.0000      2.0720      0.0720      1.9000      2.3100
# 50%          104.0000      2.7180      0.1140      2.5100      2.9990
# 75%          243.0000      3.7520      0.1910      3.4990      4.1500
# max         4167.0000     99.3570     10.7480     90.0000    120.0000
#
#        coef_price       month        year
# count 106823.0000 106823.0000 106823.0000
# mean       0.0454      6.4840   2011.8023
# std        0.0251      3.4434      4.3915
# min        0.0000      1.0000   2004.0000
# 25%        0.0290      4.0000   2008.0000
# 50%        0.0410      6.0000   2012.0000
# 75%        0.0580      9.0000   2016.0000
# max        0.3950     12.0000   2019.0000

# %%
df['start_date'] = pd.to_datetime(df['start_date'])

# %%
df['end_date'] = pd.to_datetime(df['end_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   start_date        106823 non-null  datetime64[ns]
#  1   end_date          106823 non-null  datetime64[ns]
#  2   region            106823 non-null  object
#  3   state             106823 non-null  object
#  4   Product_Kind      106823 non-null  object
#  5   n_gas_stations    106823 non-null  int64
#  6   Measuring unit    106823 non-null  object
#  7   avg_price         106823 non-null  float64
#  8   sd_price          106823 non-null  float64
#  9   min_price         106823 non-null  float64
#  10  max_price         106823 non-null  float64
#  11  avg_price_margin  106823 non-null  object
#  12  coef_price        106823 non-null  float64
#  13  dist_avg_price    106823 non-null  object
#  14  dist_sd_price     106823 non-null  object
#  15  dist_min_price    106823 non-null  object
#  16  dist_max_price    106823 non-null  object
#  17  coef_dist         106823 non-null  object
#  18  month             106823 non-null  int64
#  19  year              106823 non-null  int64
# dtypes: datetime64[ns](2), float64(5), int64(3), object(10)
# memory usage: 16.3+ MB

# %%
# Translate some values to english
regions = {"SUL":"SOUTH", "SUDESTE":"SOUTHEAST", "CENTRO OESTE":"MIDWEST", 
            "NORTE":"NORTH", "NORDESTE":"NORTHEAST"}
df["region"] = df['region'].map(regions)

# %%
# Translate some values to english
Product_Kind = {"ÓLEO DIESEL":"DIESEL", "GASOLINA COMUM":"REGULAR GASOLINE", "GLP":"LPG", 
            "ETANOL HIDRATADO":"HYDROUS ETHANOL", "GNV":"NATURAL GAS", "ÓLEO DIESEL S10":"DIESEL S10"}
df["Product_Kind"] = df['Product_Kind'].map(Product_Kind)

# %%
df.head()
# Out:
#    n_gas_stations  Measuring unit  avg_price  sd_price  min_price  max_price
# 0             127             NaN     1.2880    0.0160     1.1900     1.3500  \
# 1             387             NaN     1.1620    0.1140     0.8900     1.4490
# 2             192             NaN     1.3890    0.0970     1.1800     1.7600
# 3             162             NaN     1.2620    0.0700     1.0900     1.5090
# 4             103             NaN     1.1810    0.0780     1.0500     1.4000
#
#    avg_price_margin  coef_price  dist_avg_price  dist_sd_price  ...
# 0            0.4630      0.0120          0.8250         0.1100  ...  \
# 1            0.3990      0.0980          0.7630         0.0880  ...
# 2            0.4190      0.0700          0.9700         0.0950  ...
# 3            0.4320      0.0550          0.8300         0.1190  ...
# 4            0.2400      0.0660          0.9410         0.0770  ...
#
#    state_RONDONIA  state_RORAIMA  state_SANTA CATARINA  state_SAO PAULO
# 0           False          False                 False            False  \
# 1           False          False                 False            False
# 2           False          False                 False            False
# 3           False          False                 False            False
# 4           False          False                 False            False
#
#    state_SERGIPE  state_TOCANTINS  region_NORTH  region_NORTHEAST
# 0          False            False         False             False  \
# 1          False            False         False             False
# 2          False            False         False             False
# 3          False            False         False             False
# 4          False            False         False              True
#
#    region_SOUTH  region_SOUTHEAST
# 0         False             False
# 1         False             False
# 2         False             False
# 3         False             False
# 4         False             False
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Handling Missing Values

# %%
df.isnull().sum()
# Out:
# start_date          0
# end_date            0
# region              0
# state               0
# Product_Kind        0
# n_gas_stations      0
# Measuring unit      0
# avg_price           0
# sd_price            0
# min_price           0
# max_price           0
# avg_price_margin    0
# coef_price          0
# dist_avg_price      0
# dist_sd_price       0
# dist_min_price      0
# dist_max_price      0
# coef_dist           0
# month               0
# year                0
# dtype: int64

# %%
#Return percentage of missing values in each column  
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{}  -  {}%'.format(col, round(pct_missing*100)))
# Out:
# start_date  -  0%
# end_date  -  0%
# region  -  0%
# state  -  0%
# Product_Kind  -  0%
# n_gas_stations  -  0%
# Measuring unit  -  0%
# avg_price  -  0%
# sd_price  -  0%
# min_price  -  0%
# max_price  -  0%
# avg_price_margin  -  0%
# coef_price  -  0%
# dist_avg_price  -  0%
# dist_sd_price  -  0%
# dist_min_price  -  0%
# dist_max_price  -  0%
# coef_dist  -  0%
# month  -  0%
# year  -  0%

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   start_date        106823 non-null  datetime64[ns]
#  1   end_date          106823 non-null  datetime64[ns]
#  2   region            106823 non-null  object
#  3   state             106823 non-null  object
#  4   Product_Kind      106823 non-null  object
#  5   n_gas_stations    106823 non-null  int64
#  6   Measuring unit    106823 non-null  object
#  7   avg_price         106823 non-null  float64
#  8   sd_price          106823 non-null  float64
#  9   min_price         106823 non-null  float64
#  10  max_price         106823 non-null  float64
#  11  avg_price_margin  106823 non-null  object
#  12  coef_price        106823 non-null  float64
#  13  dist_avg_price    106823 non-null  object
#  14  dist_sd_price     106823 non-null  object
#  15  dist_min_price    106823 non-null  object
#  16  dist_max_price    106823 non-null  object
#  17  coef_dist         106823 non-null  object
#  18  month             106823 non-null  int64
#  19  year              106823 non-null  int64
# dtypes: datetime64[ns](2), float64(5), int64(3), object(10)
# memory usage: 16.3+ MB

# %% [markdown]
# # 3. Analysis and Visualization

# %%
# Checking null values
df.isnull().sum()
# Out:
# start_date          0
# end_date            0
# region              0
# state               0
# Product_Kind        0
# n_gas_stations      0
# Measuring unit      0
# avg_price           0
# sd_price            0
# min_price           0
# max_price           0
# avg_price_margin    0
# coef_price          0
# dist_avg_price      0
# dist_sd_price       0
# dist_min_price      0
# dist_max_price      0
# coef_dist           0
# month               0
# year                0
# dtype: int64

# %% [markdown]
# ## Productive Regions

# %%
df['region'].value_counts()
# Out:
# region
# NORTHEAST    36869
# NORTH        24702
# SOUTHEAST    17047
# MIDWEST      15429
# SOUTH        12776
# Name: count, dtype: int64

# %%
sns.countplot(x = df['region'])
plt.title(" Productive Regions ", size=20 )
plt.show()

# %%
plt.pie(df['region'].value_counts(),labels=df['region'].value_counts().index,
        autopct ='%1.2f%%',shadow = True, explode = [0.1,0,0,0,0])
plt.title(" Productive Regions  ", size=20 )
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Productive States

# %%
df['state'].value_counts()
# Out:
# state
# RIO DE JANEIRO         4263
# SAO PAULO              4263
# RIO GRANDE DO SUL      4263
# BAHIA                  4263
# CEARA                  4263
# PARAIBA                4263
# SANTA CATARINA         4262
# RIO GRANDE DO NORTE    4262
# PERNAMBUCO             4262
# MINAS GERAIS           4261
# ESPIRITO SANTO         4260
# SERGIPE                4259
# PARANA                 4251
# ALAGOAS                4250
# MATO GROSSO DO SUL     4246
# MATO GROSSO            4037
# AMAZONAS               3889
# GOIAS                  3663
# PIAUI                  3548
# MARANHAO               3499
# PARA                   3497
# DISTRITO FEDERAL       3483
# TOCANTINS              3483
# ACRE                   3480
# RONDONIA               3479
# RORAIMA                3471
# AMAPA                  3403
# Name: count, dtype: int64

# %% [markdown]
# **as we see states production is close to each other**

# %%
sns.countplot(y = df['state'])
plt.title(" Productive States ", size=20 )
plt.show()

# %% [markdown]
# ## Products Count

# %%
df['Product_Kind'].value_counts()
# Out:
# Product_Kind
# REGULAR GASOLINE    21194
# DIESEL              21194
# LPG                 21186
# HYDROUS ETHANOL     21102
# NATURAL GAS         13034
# DIESEL S10           9113
# Name: count, dtype: int64

# %%
sns.set(rc={'figure.figsize':(20, 8)}, font_scale=1.3)
sns.countplot(x = df['Product_Kind'])
plt.title(" Products Count from 2004 to 2019  ", size=20 )
plt.show()

# %%
plt.pie(df['Product_Kind'].value_counts(),labels=df['Product_Kind'].value_counts().index,
        autopct ='%1.2f%%',shadow = True,explode = [0.1,0.1,0,0,0,0])
plt.title(" Products Count ", size=20 )
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Years Production

# %%
df['year'].value_counts()
# Out:
# year
# 2017    7990
# 2014    7932
# 2013    7921
# 2016    7873
# 2018    7823
# 2015    7771
# 2012    6634
# 2006    6598
# 2010    6489
# 2011    6487
# 2007    6475
# 2008    6453
# 2009    6232
# 2005    6186
# 2004    4205
# 2019    3754
# Name: count, dtype: int64

# %% [markdown]
# **as we see years production is close to each othe except 2004 and 2019**

# %%
sns.countplot(x=df['year'])
plt.title("Years Production", size=20)
plt.show()

# %% [markdown]
# ## Measuring Unit Count

# %%
df['Measuring unit'].value_counts()
# Out:
# Measuring unit
# R$/l       72603
# R$/13Kg    21186
# R$/m3      13034
# Name: count, dtype: int64

# %%
sns.countplot(x = df['Measuring unit'])
plt.title(" Measuring unit used from 2004 to 2019  ", size=20 )
plt.show()

# %%
plt.pie(df['Measuring unit'].value_counts(),labels=df['Measuring unit'].value_counts().index,
        autopct ='%1.2f%%',shadow = True,explode = [0.1,0,0])
plt.title(" Measuring unit used from 2004 to 2019  ", size=20 )
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Frequent Product in each State

# %%
most_product_in_each_state = df.groupby('state').agg(lambda x:x.value_counts().index[0])['Product_Kind']
pd.DataFrame(most_product_in_each_state)
# Out:
#                          Product_Kind
# state
# ACRE                 REGULAR GASOLINE
# ALAGOAS               HYDROUS ETHANOL
# AMAPA                REGULAR GASOLINE
# AMAZONAS              HYDROUS ETHANOL
# BAHIA                 HYDROUS ETHANOL
# CEARA                 HYDROUS ETHANOL
# DISTRITO FEDERAL      HYDROUS ETHANOL
# ESPIRITO SANTO        HYDROUS ETHANOL
# GOIAS                 HYDROUS ETHANOL
# MARANHAO              HYDROUS ETHANOL
# MATO GROSSO           HYDROUS ETHANOL
# MATO GROSSO DO SUL    HYDROUS ETHANOL
# MINAS GERAIS          HYDROUS ETHANOL
# PARA                  HYDROUS ETHANOL
# PARAIBA               HYDROUS ETHANOL
# PARANA                HYDROUS ETHANOL
# PERNAMBUCO           REGULAR GASOLINE
# PIAUI                 HYDROUS ETHANOL
# RIO DE JANEIRO        HYDROUS ETHANOL
# RIO GRANDE DO NORTE   HYDROUS ETHANOL
# RIO GRANDE DO SUL     HYDROUS ETHANOL
# RONDONIA              HYDROUS ETHANOL
# RORAIMA              REGULAR GASOLINE
# SANTA CATARINA       REGULAR GASOLINE
# SAO PAULO             HYDROUS ETHANOL
# SERGIPE               HYDROUS ETHANOL
# TOCANTINS            REGULAR GASOLINE

# %%
states = most_product_in_each_state.index
product_type = most_product_in_each_state.values

# %%
sns.set(rc={'figure.figsize':(8, 8)}, font_scale=1.3)
sns.swarmplot(x=most_product_in_each_state,y= states)
sns.stripplot(x=most_product_in_each_state,y= states)
plt.title("frequent product in each state", size=18)
plt.show()

# %% [markdown]
# ## Gas Stations vs Products
# > Average of no of Gas Stations for each product

# %%
sns.displot(df['n_gas_stations'],height = 7,aspect =1.4,bins=100)
# Out:
# c:\Users\thees\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set(rc={'figure.figsize':(20, 8)}, font_scale=1.3)
plt.title(" Gas Stations Number for Products ", size=20 )
sns.barplot(y= df['n_gas_stations'],x=df['Product_Kind'])
# Out:
# <Axes: title={'center': ' Gas Stations Number for Products '}, xlabel='Product_Kind', ylabel='n_gas_stations'>

# %% [markdown]
# ## Frequent Product in each Year

# %%
most_product_in_each_year = df.groupby('year').agg(lambda x:x.value_counts().index[0])['Product_Kind']
pd.DataFrame(most_product_in_each_year).T
# Out:
# year                     2004              2005             2006
# Product_Kind  HYDROUS ETHANOL  REGULAR GASOLINE  HYDROUS ETHANOL  \
#
# year                     2007             2008             2009
# Product_Kind  HYDROUS ETHANOL  HYDROUS ETHANOL  HYDROUS ETHANOL  \
#
# year                     2010             2011             2012
# Product_Kind  HYDROUS ETHANOL  HYDROUS ETHANOL  HYDROUS ETHANOL  \
#
# year                     2013    2014    2015    2016    2017    2018    2019
# Product_Kind  HYDROUS ETHANOL  DIESEL  DIESEL  DIESEL  DIESEL  DIESEL  DIESEL

# %%
years = most_product_in_each_year.index
product_type = most_product_in_each_year.values

# %%
sns.set(rc={'figure.figsize':(8, 8)}, font_scale=1.3)
sns.swarmplot(x=most_product_in_each_year,y= years)
sns.stripplot(x=most_product_in_each_year,y= years)
plt.title("frequent product in each year", size=18)
plt.show()

# %%
plt.bar(years,most_product_in_each_year)
# Out:
# <BarContainer object of 16 artists>

# %% [markdown]
# ## Analysis Days for each product
# > needed days for analysis for each product from 2004 to 2019

# %%
from datetime import datetime, timedelta
df['Analysis_Days']=(df['end_date'] - df['start_date']) / timedelta(days=1)

# %%
df['Analysis_Days'].value_counts()
# Out:
# Analysis_Days
# 6.0000    106823
# Name: count, dtype: int64

# %% [markdown]
# **as we see analysis days need for any product is 6 days**

# %%
sns.set(rc={'figure.figsize':(20, 8)}, font_scale=1.3)
plt.title(" Analysis Days for each Product ", size=20 )
sns.barplot(y= df['Analysis_Days'],x=df['Product_Kind'])
# Out:
# <Axes: title={'center': ' Analysis Days for each Product '}, xlabel='Product_Kind', ylabel='Analysis_Days'>

# %% [markdown]
# ## Average Industrialization Price for products
# > for average of Average Industrialization Price for each product from 2004 to 2019

# %%
plt.title(" Average Industrialization Price  ", size=20 )
sns.barplot(y= df['avg_price'],x=df['Product_Kind'])
# Out:
# <Axes: title={'center': ' Average Industrialization Price  '}, xlabel='Product_Kind', ylabel='avg_price'>

# %% [markdown]
# ## Maximium Industrialization Price for products
# > for average of Max Industrialization Price for each product from 2004 to 2019

# %%
plt.title(" Maximium Industrialization Price  ", size=20 )
sns.barplot(y= df['max_price'],x=df['Product_Kind'])
# Out:
# <Axes: title={'center': ' Maximium Industrialization Price  '}, xlabel='Product_Kind', ylabel='max_price'>

# %% [markdown]
# ## Minimum Industrialization Price for products
# > for average of Min Industrialization Price for each product from 2004 to 2019

# %%
plt.title(" Minimum Industrialization Price  ", size=20 )
sns.barplot(y= df['min_price'],x=df['Product_Kind'])
# Out:
# <Axes: title={'center': ' Minimum Industrialization Price  '}, xlabel='Product_Kind', ylabel='min_price'>

# %% [markdown]
# ## Handling Categorical Data

# %%
df = pd.get_dummies(df, columns=['Product_Kind','state','region'], drop_first=True)

# %%
Unit_dict = {'R$/l':0, 'R$/13Kg':1, 'R$/m3':2}
df['Measuring unit'] = df['Measuring unit'].map(Unit_dict)
df.head()
# Out:
#    n_gas_stations  Measuring unit  avg_price  sd_price  min_price  max_price
# 0             127             NaN     1.2880    0.0160     1.1900     1.3500  \
# 1             387             NaN     1.1620    0.1140     0.8900     1.4490
# 2             192             NaN     1.3890    0.0970     1.1800     1.7600
# 3             162             NaN     1.2620    0.0700     1.0900     1.5090
# 4             103             NaN     1.1810    0.0780     1.0500     1.4000
#
#    avg_price_margin  coef_price  dist_avg_price  dist_sd_price  ...
# 0            0.4630      0.0120          0.8250         0.1100  ...  \
# 1            0.3990      0.0980          0.7630         0.0880  ...
# 2            0.4190      0.0700          0.9700         0.0950  ...
# 3            0.4320      0.0550          0.8300         0.1190  ...
# 4            0.2400      0.0660          0.9410         0.0770  ...
#
#    state_RONDONIA  state_RORAIMA  state_SANTA CATARINA  state_SAO PAULO
# 0           False          False                 False            False  \
# 1           False          False                 False            False
# 2           False          False                 False            False
# 3           False          False                 False            False
# 4           False          False                 False            False
#
#    state_SERGIPE  state_TOCANTINS  region_NORTH  region_NORTHEAST
# 0          False            False         False             False  \
# 1          False            False         False             False
# 2          False            False         False             False
# 3          False            False         False             False
# 4          False            False         False              True
#
#    region_SOUTH  region_SOUTHEAST
# 0         False             False
# 1         False             False
# 2         False             False
# 3         False             False
# 4         False             False
#
# [5 rows x 50 columns]

# %%
df.drop(['start_date'	,'end_date','Analysis_Days'],axis=1, inplace =True)

# %% [markdown]
# # 4. Modelling

# %% [markdown]
# ## Spliting

# %%
x = df.drop(['avg_price'],axis=1)

# %%
x.head()
# Out:
#    n_gas_stations  Measuring unit  sd_price  min_price  max_price
# 0             127               0    0.0160     1.1900     1.3500  \
# 1             387               0    0.1140     0.8900     1.4490
# 2             192               0    0.0970     1.1800     1.7600
# 3             162               0    0.0700     1.0900     1.5090
# 4             103               0    0.0780     1.0500     1.4000
#
#    avg_price_margin  coef_price  dist_avg_price  dist_sd_price
# 0            0.4630      0.0120          0.8250         0.1100  \
# 1            0.3990      0.0980          0.7630         0.0880
# 2            0.4190      0.0700          0.9700         0.0950
# 3            0.4320      0.0550          0.8300         0.1190
# 4            0.2400      0.0660          0.9410         0.0770
#
#    dist_min_price  ...  state_RONDONIA  state_RORAIMA  state_SANTA CATARINA
# 0          0.4201  ...           False          False                 False  \
# 1          0.5013  ...           False          False                 False
# 2          0.5614  ...           False          False                 False
# 3          0.5991  ...           False          False                 False
# 4          0.7441  ...           False          False                 False
#
#    state_SAO PAULO  state_SERGIPE  state_TOCANTINS  region_NORTH
# 0            False          False            False         False  \
# 1            False          False            False         False
# 2            False          False            False         False
# 3            False          False            False         False
# 4            False          False            False         False
#
#    region_NORTHEAST  region_SOUTH  region_SOUTHEAST
# 0             False         False             False
# 1             False         False             False
# 2             False         False             False
# 3             False         False             False
# 4              True         False             False
#
# [5 rows x 49 columns]

# %%
y = df['avg_price']

# %%
y.head()
# Out:
# 0   1.2880
# 1   1.1620
# 2   1.3890
# 3   1.2620
# 4   1.1810
# Name: avg_price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test, y_train , y_test = train_test_split(x,y,test_size=0.25)

# %%
x_train
# Out:
#        n_gas_stations  Measuring unit  sd_price  min_price  max_price
# 71408              95               0    0.0970     3.1490     3.6300  \
# 25542             163               1    1.7430    26.0000    34.0000
# 98171             864               0    0.1440     3.1700     4.7400
# 56246             176               0    0.0510     2.0500     2.3430
# 47896              80               0    0.0680     1.9400     2.2100
# ...               ...             ...       ...        ...        ...
# 29955             306               1    2.0270    27.9900    38.0000
# 48593             367               0    0.0620     1.7690     2.1000
# 19345              61               0    0.0880     2.4800     2.8500
# 26908             943               1    1.1790    30.0000    40.0000
# 26867              59               1    0.7440    30.0000    34.0000
#
#        avg_price_margin  coef_price  dist_avg_price  dist_sd_price
# 71408            0.4940      0.0300          2.7670         0.0580  \
# 25542            5.3710      0.0570         25.0210         1.9200
# 98171            0.3680      0.0390          3.3300         0.1260
# 56246            0.2420      0.0240          1.9220         0.0320
# 47896            0.1610      0.0340          1.8580         0.0290
# ...                 ...         ...             ...            ...
# 29955            6.9110      0.0620         25.7220         2.4480
# 48593            0.2120      0.0320          1.7310         0.0320
# 19345            0.5200      0.0320          2.2100         0.0490
# 26908            5.3670      0.0340         28.8300         2.9160
# 26867            7.2540      0.0230         25.4120         0.9560
#
#        dist_min_price  ...  state_RONDONIA  state_RORAIMA
# 71408          2.6464  ...            True          False  \
# 25542         21.0000  ...           False          False
# 98171          2.4900  ...           False          False
# 56246          1.8262  ...           False          False
# 47896          1.7944  ...           False          False
# ...               ...  ...             ...            ...
# 29955         22.1000  ...           False          False
# 48593          1.6312  ...           False          False
# 19345          2.1300  ...           False          False
# 26908         22.0000  ...           False          False
# 26867         24.0000  ...           False          False
#
#        state_SANTA CATARINA  state_SAO PAULO  state_SERGIPE  state_TOCANTINS
# 71408                 False            False          False            False  \
# 25542                 False            False          False            False
# 98171                 False             True          False            False
# 56246                 False            False          False            False
# 47896                 False            False          False            False
# ...                     ...              ...            ...              ...
# 29955                 False            False          False            False
# 48593                 False            False          False            False
# 19345                 False            False          False             True
# 26908                  True            False          False            False
# 26867                 False            False           True            False
#
#        region_NORTH  region_NORTHEAST  region_SOUTH  region_SOUTHEAST
# 71408          True             False         False             False
# 25542         False              True         False             False
# 98171         False             False         False              True
# 56246         False             False         False              True
# 47896         False             False         False             False
# ...             ...               ...           ...               ...
# 29955         False             False         False              True
# 48593         False             False          True             False
# 19345          True             False         False             False
# 26908         False             False          True             False
# 26867         False              True         False             False
#
# [77544 rows x 49 columns]

# %%
x_train.shape
# Out:
# (77544, 49)

# %%
x_test
# Out:
# array([[-0.02639699, -0.60667915, -0.39583935, ...,  1.37210662,
#         -0.36777841, -0.43810886],
#        [ 0.66541534, -0.60667915, -0.43372188, ..., -0.72880634,
#          2.71902853, -0.43810886],
#        [-0.53421667, -0.60667915, -0.444121  , ..., -0.72880634,
#         -0.36777841, -0.43810886],
#        ...,
#        [ 0.80034328, -0.60667915, -0.41069524, ..., -0.72880634,
#          2.71902853, -0.43810886],
#        [-0.50723109, -0.60667915, -0.35944241, ..., -0.72880634,
#         -0.36777841, -0.43810886],
#        [-0.5293102 ,  2.35655642, -0.45526292, ...,  1.37210662,
#         -0.36777841, -0.43810886]])

# %%
x_test.shape
# Out:
# (25848, 49)

# %%
y_train
# Out:
# 71408    3.2610
# 25542   30.3920
# 98171    3.6980
# 56246    2.1640
# 47896    2.0190
#           ...
# 29955   32.6330
# 48593    1.9430
# 19345    2.7300
# 26908   34.1970
# 26867   32.6660
# Name: avg_price, Length: 77544, dtype: float64

# %%
y_train.shape
# Out:
# (77544,)

# %%
y_test.head()
# Out:
# 64530    2.9340
# 1349     1.6590
# 73518    3.1790
# 51835    2.0520
# 98521   65.3760
# Name: avg_price, dtype: float64

# %%
y_test.shape
# Out:
# (25848,)

# %% [markdown]
# ## Scalling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
scalar.fit(x_train)
x_train = scalar.transform(x_train)

# %%
x_test=scalar.transform(x_test)

# %%
x_train
# Out:
# array([[-0.3551305 , -0.60667915, -0.41143804, ..., -0.72880634,
#         -0.36777841, -0.43810886],
#        [-0.18831051,  0.87493864,  0.81120192, ...,  1.37210662,
#         -0.36777841, -0.43810886],
#        [ 1.53140736, -0.60667915, -0.37652669, ..., -0.72880634,
#         -0.36777841,  2.28253771],
#        ...,
#        [-0.4385405 , -0.60667915, -0.41812319, ..., -0.72880634,
#         -0.36777841, -0.43810886],
#        [ 1.72521295,  0.87493864,  0.39226575, ..., -0.72880634,
#          2.71902853, -0.43810886],
#        [-0.44344697,  0.87493864,  0.06915009, ...,  1.37210662,
#         -0.36777841, -0.43810886]])

# %%
x_test
# Out:
# array([[-0.02639699, -0.60667915, -0.39583935, ...,  1.37210662,
#         -0.36777841, -0.43810886],
#        [ 0.66541534, -0.60667915, -0.43372188, ..., -0.72880634,
#          2.71902853, -0.43810886],
#        [-0.53421667, -0.60667915, -0.444121  , ..., -0.72880634,
#         -0.36777841, -0.43810886],
#        ...,
#        [ 0.80034328, -0.60667915, -0.41069524, ..., -0.72880634,
#          2.71902853, -0.43810886],
#        [-0.50723109, -0.60667915, -0.35944241, ..., -0.72880634,
#         -0.36777841, -0.43810886],
#        [-0.5293102 ,  2.35655642, -0.45526292, ...,  1.37210662,
#         -0.36777841, -0.43810886]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import  KNeighborsRegressor
from sklearn.svm import  SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
models  = {
    "LR" : LinearRegression(n_jobs=-1),
    "XGB" : XGBRegressor(n_estimators=100,n_jobs=-1,objective ='reg:squarederror'),
    "KNN" : KNeighborsRegressor(n_neighbors=7),
    "GradientBoosting"  :  GradientBoostingRegressor(),
    "DT" : DecisionTreeRegressor(),
    "Random_Forest" : RandomForestRegressor(n_estimators=100,n_jobs=-1)
}

# %% [markdown]
# # 5.Evaluation

# %%
for name, model in models.items():
    print(f'Using model: {name}')
    model.fit(x_train, y_train)
    print(f'Training Score: {model.score(x_train, y_train)}')
    print(f'Test Score: {model.score(x_test, y_test)}')  
    print('--'*50)
# Out:
# Using model: LR
# Training Score: 1.0
# Test Score: 1.0
# ----------------------------------------------------------------------------------------------------
# Using model: XGB
# Training Score: 0.9999704073755205
# Test Score: 0.9999040657813929
# ----------------------------------------------------------------------------------------------------
# Using model: KNN
# Training Score: 0.999623292832375
# Test Score: 0.9995573848509298
# ----------------------------------------------------------------------------------------------------
# Using model: GradientBoosting
# Training Score: 0.9994557426317561
# Test Score: 0.999412337275683
# ----------------------------------------------------------------------------------------------------
# Using model: DT
# Training Score: 1.0
# Test Score: 0.9997506099585
# ----------------------------------------------------------------------------------------------------
# Using model: Random_Forest
# Training Score: 0.9999830199104337
# Test Score: 0.9998729331856943
# ----------------------------------------------------------------------------------------------------

# %%
model = XGBRegressor(objective ='reg:squarederror')

# %%
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred = model.predict(x_test)

# %%
pd.options.display.float_format = '{:.4f}'.format
y_compare={'Actual Output':y_test, 'Predicted Output':y_pred}
pd.DataFrame(y_compare)
# Out:
#        Actual Output  Predicted Output
# 64530         2.9340            2.9554
# 1349          1.6590            1.6983
# 73518         3.1790            3.2025
# 51835         2.0520            2.0345
# 98521        65.3760           66.8336
# ...              ...               ...
# 96991         3.4960            3.4766
# 91619        65.5020           64.8643
# 21402         2.5950            2.6274
# 87586         3.4840            3.4742
# 41153         1.8000            1.7590
#
# [25848 rows x 2 columns]

# %%
print('Training Score is : ' , model.score(x_train, y_train))
print( '--'*50)
print('Testing Score is : ' , model.score(x_test, y_test))
# Out:
# Training Score is :  0.9999704073755205
# ----------------------------------------------------------------------------------------------------
# Testing Score is :  0.9999040657813929

# %%
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error

# %%
MAE = mean_absolute_error(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
medien_error = median_absolute_error(y_test,y_pred)

# %%
print(' Absolute Mean Error :',MAE)
print('--'*50)
print(' Absolute Median Error :',medien_error)
print('--'*50)
print(' Mean Squared Error :',MSE)
print('--'*50)
print(' Root Mean Squared Error :',np.sqrt(MSE))
# Out:
#  Absolute Mean Error : 0.06804075579411178
# ----------------------------------------------------------------------------------------------------
#  Absolute Median Error : 0.02318075370788586
# ----------------------------------------------------------------------------------------------------
#  Mean Squared Error : 0.03003498274486925
# ----------------------------------------------------------------------------------------------------
#  Root Mean Squared Error : 0.17330603782000573

# %% [markdown]
# **Conclusion**
#
# I have tested my model on various model.Finally I took XGBRegressor model and gave pretty good testing score very close to training score.
